# %% [markdown]
# <a href="https://colab.research.google.com/github/frostd1022/neur_256_spring26/blob/main/Coding_Homework_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# David Frost
#
# *Intro to Neural Data Analaysis*
#
# **2/10/26**

# %%
#importing pandas into the code cell
import pandas as pd

# %%
#Code cell that turns vrestsst.csv into a Pandas DataFrame

url = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_pvalb.csv'
pandas_data1 = pd.read_csv(url)

url = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_sst.csv'
pandas_data2 = pd.read_csv(url)

# %%
#converting pandas_data1 into a list
data1 = pandas_data1.values.tolist()
data2 = pandas_data2.values.tolist()

# %%
#code cell that flattens data1 and data 2
import numpy as np

data1 = np.squeeze(data1)
data2 = np.squeeze(data2)

# %%
#code cell that prints the length of data1
print(len(data1))
# Out:
# 499

# %%
print(data2[2:6])
# Out:
# [[-71.16118393], [-76.35402679], [-70.89105013], [-64.11880341]]

# %%
print(data1[-3:-1])
# Out:
# [[-71.44608222], [-49.80412917]]

# %%
print(type(data2))
# Out:
# <class 'list'>

# %%
import matplotlib.pyplot as plt
plt.hist(data1)
plt.xlabel('Resting Membrane Potential')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import matplotlib.pyplot as plt
plt.hist(data2)
plt.xlabel('Resting Membrane Potential')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# I notice that in data2, the data is more focused with most datapoints being between -65 and -75mv. The range in the histogram of data1 however, is much more spread out, with common numbers ranging from -80mv to -60mv.

# %%
data3 = data1 + data2

# %%
print(data3[-1])
# Out:
# [-75.10678711]
